# %% [markdown]
# <a href="https://colab.research.google.com/github/waraporn19/data_viz/blob/main/Quiz2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
path = '/content/drive/My Drive/Data_mid'#ให้ข้อมูลที่อยู่ใน Drive แทนด้วยชื่อ path

# %%
d1 = os.path.join(path,'3.-41-58.csv')
print(d1)
# Out:
# /content/drive/My Drive/Data_mid/3.-41-58.csv

# %%
data_r = pd.read_csv(d1)
data_r
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-28-c0975a439230> in <module>()
# ----> 1 data_r = pd.read_csv(d1)
#       2 data_r
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
#     687
# ...

# %% [markdown]
# ใช้ excel

# %%
import pandas as pd #เรียกใช้ packet ชื่อว่า pandas แล้วเปลี่ยนเป็น pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data_1 = os.path.join(path,'3.-41-58.csv')

# %% [markdown]
# #เฉลย

# %%
import pandas as pd

# %%
data_csv = pd.read_csv('3.-41-58.csv', encoding='iso-8859-11')#encoding ใช้อ่านไฟล์ภาษาไทย
data_csv.iloc[:10,:] #ดูตั้งแต่หัวตารางลงมา
# Out:
#     รายได้เฉลี่ยต่อเดือนต่อครัวเรือน จำแนกตามภาค และจังหวัด พ.ศ. 2541 - 2558  ... Unnamed: 66
# 0    Average Monthly Income Per Household: 1998 - 2015                        ...         NaN
# 1                                                  NaN                        ...         NaN
# 2                                       ภาค และจังหวัด                        ...         NaN
# 3                                                  NaN                        ...         NaN
# 4                                                  NaN                        ...         NaN
# ..                                                 ...                        ...         ...
# 104                                                NaN                        ...         NaN
# 105                                                NaN                        ...         NaN
# 106                                                NaN                        ...         NaN
# ...

# %%
data_csv = pd.read_csv('3.-41-58.csv', encoding='iso-8859-11',header= 3)#encoding ใช้อ่านไฟล์ภาษาไทย # header กำหนดหัวตารางที่ี่ต้องการมา ว่าอยู่แถวที่เท่าไร
data_csv.iloc[:10,:] #ดูตั้งแต่หัวตารางลงมา
# Out:
#           ภาค และจังหวัด Unnamed: 1  ... Unnamed: 65 Unnamed: 66
# 0                    NaN        NaN  ...         NaN         NaN
# 1                    NaN        NaN  ...         NaN         NaN
# 2       ทั่วราชอาณาจักร         NaN  ...         NaN         NaN
# 3              ตอนพิเศษ         NaN  ...         NaN         NaN
# 4         กรุงเทพมหานคร         NaN  ...         NaN         NaN
# 5           สมุทรปราการ         NaN  ...         NaN         NaN
# 6               นนทบุรี         NaN  ...         NaN         NaN
# 7              ปทุมธานี         NaN  ...         NaN         NaN
# 8               ภาคกลาง         NaN  ...         NaN         NaN
# 9       พระนครศรีอยุธยา         NaN  ...         NaN         NaN
#
# [10 rows x 67 columns]

# %%
data_csv.head(10).dropna(subset=['ภาค และจังหวัด']).iloc[:,:13]#.dropna(subset ตัดมาแค่ 'ภาค และจังหวัด'  และตัด missing ออก #.ilocตัดcolum ที่ไม่เอาออก ตั้งแต่  colum 13
# Out:
#           ภาค และจังหวัด Unnamed: 1  ...      2558             Region and province
# 2       ทั่วราชอาณาจักร         NaN  ...   26,915                   Whole Kingdom
# 3              ตอนพิเศษ         NaN  ...   41,002                 Greater Bangkok
# 4         กรุงเทพมหานคร         NaN  ...   45,572                         Bangkok
# 5           สมุทรปราการ         NaN  ...   25,457                    Samut Prakan
# 6               นนทบุรี         NaN  ...   36,884                      Nonthaburi
# 7              ปทุมธานี         NaN  ...   41,057                    Pathum Thani
# 8               ภาคกลาง         NaN  ...   26,601                  Central Region
# 9       พระนครศรีอยุธยา         NaN  ...   28,379        Phra Nakhon Si Ayutthaya
#
# [8 rows x 13 columns]

# %%
data_csv.dropna(axis=1,subset=[2])#.dropna(axis คือตัดแถวที่มี Missing ออก
# Out:
#           ภาค และจังหวัด      2541  ...      2558 Region and province
# 0                    NaN    (1998)  ...    (2015)                 NaN
# 1                    NaN       NaN  ...       NaN                 NaN
# 2       ทั่วราชอาณาจักร    12,492   ...   26,915       Whole Kingdom
# 3              ตอนพิเศษ    24,929   ...   41,002     Greater Bangkok
# 4         กรุงเทพมหานคร    26,054   ...   45,572             Bangkok
# ..                   ...       ...  ...       ...                 ...
# 101                  NaN       NaN  ...       NaN                 NaN
# 102                  NaN       NaN  ...       NaN                 NaN
# 103                  NaN       NaN  ...       NaN                 NaN
# 104                  NaN       NaN  ...       NaN                 NaN
# 105                  NaN       NaN  ...       NaN                 NaN
#
# [106 rows x 12 columns]
