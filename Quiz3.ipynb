# %% [markdown]
# <a href="https://colab.research.google.com/github/waraporn19/data_viz/blob/main/Quiz3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data_csv = pd.read_excel('/content/-.57-.58-1.xls', sheet_name=0,)
data_csv
# Out:
#                                          Unnamed: 0  ...                แบบ สขร. 1
# 0   สรุปผลการดำเนินการจัดซื้อในรอบเดือน ตุลาคม 2557  ...                       NaN
# 1        สำนักงานปลัดกระทรวงวิทยาศาสตร์และเทคโนโลยี  ...                       NaN
# 2                                               NaN  ...                       NaN
# 3                                             ลำดับ  ...  เหตุผลที่คัดเลือกโดยสรุป
# 4                                               ที่  ...                       NaN
# 5                                                 1  ...   เป็นผู้ให้บริการจำหน่าย
# 6                                                 2  ...   เป็นผู้ให้บริการจำหน่าย
# 7                                                 3  ...   เป็นผู้ให้บริการจำหน่าย
# 8                                                 4  ...   เป็นผู้ให้บริการจำหน่าย
# 9                                                 5  ...   เป็นผู้ให้บริการจำหน่าย
# ...

# %% [markdown]
# เฉลย

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
path = '/content/drive/My Drive/Dataviz_2021'
os.listdir(path)
# Out:
# ['covid-19-daily_data_dictionary (1).xlsx',
#  'pm-18-jan-2021.csv',
#  '-.57-.58-1.xls']

# %%
file_path = os.path.join(path,'-.57-.58-1.xls')
print(file_path)
# Out:
# /content/drive/My Drive/Dataviz_2021/-.57-.58-1.xls

# %%
sale_df= pd.read_excel(file_path,sheet_name=0,skiprows=0,header=4)
sale_df
# Out:
#                                               ลำดับ  ...  เหตุผลที่คัดเลือกโดยสรุป
# 0                                               ที่  ...                       NaN
# 1                                                 1  ...   เป็นผู้ให้บริการจำหน่าย
# 2                                                 2  ...   เป็นผู้ให้บริการจำหน่าย
# 3                                                 3  ...   เป็นผู้ให้บริการจำหน่าย
# 4                                                 4  ...   เป็นผู้ให้บริการจำหน่าย
# 5                                                 5  ...   เป็นผู้ให้บริการจำหน่าย
# 6                                                 6  ...   เป็นผู้ให้บริการจำหน่าย
# 7                                                 7  ...   เป็นผู้ให้บริการจำหน่าย
# 8                                                 8  ...   เป็นผู้ให้บริการจำหน่าย
# 9                                                 9  ...   เป็นผู้ให้บริการจำหน่าย
# ...

# %%
sale = pd.read_excel(file_path,sheet_name=1,skiprows=0,header=4)
sale
# Out:
#    ลำดับ  ... เหตุผลที่คัดเลือกโดยสรุป
# 0    ที่  ...                      NaN
# 1      1  ...  เป็นผู้ให้บริการจำหน่าย
# 2      2  ...           เป็นผู้จำหน่าย
# 3      3  ...           เป็นผู้จำหน่าย
# 4      4  ...           เป็นผู้จำหน่าย
# ..   ...  ...                      ...
# 76    56  ...                      NaN
# 77    57  ...                      NaN
# 78    58  ...                      NaN
# 79    59  ...                      NaN
# 80    60  ...                      NaN
#
# [81 rows x 9 columns]

# %%
oct57 = pd.read_excel('-.57-.58-1.xls', sheet_name=0,header=4, skipfooter=20) #utf-8 -- latin1
oct57 = oct57.dropna()
oct57
# Out:
#    ลำดับ  ... เหตุผลที่คัดเลือกโดยสรุป
# 1      1  ...  เป็นผู้ให้บริการจำหน่าย
# 2      2  ...  เป็นผู้ให้บริการจำหน่าย
# 3      3  ...  เป็นผู้ให้บริการจำหน่าย
# 4      4  ...  เป็นผู้ให้บริการจำหน่าย
# 5      5  ...  เป็นผู้ให้บริการจำหน่าย
# 6      6  ...  เป็นผู้ให้บริการจำหน่าย
# 7      7  ...  เป็นผู้ให้บริการจำหน่าย
# 8      8  ...  เป็นผู้ให้บริการจำหน่าย
# 9      9  ...  เป็นผู้ให้บริการจำหน่าย
# 10    10  ...  เป็นผู้ให้บริการจำหน่าย
# 11    11  ...  เป็นผู้ให้บริการจำหน่าย
# 12    12  ...  เป็นผู้ให้บริการจำหน่าย
# 13    13  ...  เป็นผู้ให้บริการจำหน่าย
# 14    14  ...  เป็นผู้ให้บริการจำหน่าย
# 15    15  ...  เป็นผู้ให้บริการจำหน่าย
#
# [15 rows x 9 columns]

# %%
oct57 = oct57.rename(columns={'Unnamed: 5' : 'ราคาเสนอ', 'Unnamed: 7': 'ราคาซื้อ'})
oct57
# Out:
#    ลำดับ  ... เหตุผลที่คัดเลือกโดยสรุป
# 1      1  ...  เป็นผู้ให้บริการจำหน่าย
# 2      2  ...  เป็นผู้ให้บริการจำหน่าย
# 3      3  ...  เป็นผู้ให้บริการจำหน่าย
# 4      4  ...  เป็นผู้ให้บริการจำหน่าย
# 5      5  ...  เป็นผู้ให้บริการจำหน่าย
# 6      6  ...  เป็นผู้ให้บริการจำหน่าย
# 7      7  ...  เป็นผู้ให้บริการจำหน่าย
# 8      8  ...  เป็นผู้ให้บริการจำหน่าย
# 9      9  ...  เป็นผู้ให้บริการจำหน่าย
# 10    10  ...  เป็นผู้ให้บริการจำหน่าย
# 11    11  ...  เป็นผู้ให้บริการจำหน่าย
# 12    12  ...  เป็นผู้ให้บริการจำหน่าย
# 13    13  ...  เป็นผู้ให้บริการจำหน่าย
# 14    14  ...  เป็นผู้ให้บริการจำหน่าย
# 15    15  ...  เป็นผู้ให้บริการจำหน่าย
#
# [15 rows x 9 columns]

# %%
nov57 = pd.read_excel('-.57-.58-1.xls', sheet_name=0,header=4, skipfooter=20) #utf-8 -- latin1
oct57 = oct57.dropna()
oct57
# Out:
#    ลำดับ  ... เหตุผลที่คัดเลือกโดยสรุป
# 1      1  ...  เป็นผู้ให้บริการจำหน่าย
# 2      2  ...  เป็นผู้ให้บริการจำหน่าย
# 3      3  ...  เป็นผู้ให้บริการจำหน่าย
# 4      4  ...  เป็นผู้ให้บริการจำหน่าย
# 5      5  ...  เป็นผู้ให้บริการจำหน่าย
# 6      6  ...  เป็นผู้ให้บริการจำหน่าย
# 7      7  ...  เป็นผู้ให้บริการจำหน่าย
# 8      8  ...  เป็นผู้ให้บริการจำหน่าย
# 9      9  ...  เป็นผู้ให้บริการจำหน่าย
# 10    10  ...  เป็นผู้ให้บริการจำหน่าย
# 11    11  ...  เป็นผู้ให้บริการจำหน่าย
# 12    12  ...  เป็นผู้ให้บริการจำหน่าย
# 13    13  ...  เป็นผู้ให้บริการจำหน่าย
# 14    14  ...  เป็นผู้ให้บริการจำหน่าย
# 15    15  ...  เป็นผู้ให้บริการจำหน่าย
#
# [15 rows x 9 columns]

# %% [markdown]
# ## HW 8

# %%
import pandas as pd
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = '/content/drive/My Drive/Dataviz_2021'

# %%
data_path = os.path.join(path,'-.57-.58-1.xls')

# %%
data1_df = pd.read_excel(data_path,header=4,skipfooter=20)
data1_df
# Out:
#    ลำดับ  ... เหตุผลที่คัดเลือกโดยสรุป
# 0    ที่  ...                      NaN
# 1      1  ...  เป็นผู้ให้บริการจำหน่าย
# 2      2  ...  เป็นผู้ให้บริการจำหน่าย
# 3      3  ...  เป็นผู้ให้บริการจำหน่าย
# 4      4  ...  เป็นผู้ให้บริการจำหน่าย
# 5      5  ...  เป็นผู้ให้บริการจำหน่าย
# 6      6  ...  เป็นผู้ให้บริการจำหน่าย
# 7      7  ...  เป็นผู้ให้บริการจำหน่าย
# 8      8  ...  เป็นผู้ให้บริการจำหน่าย
# 9      9  ...  เป็นผู้ให้บริการจำหน่าย
# 10    10  ...  เป็นผู้ให้บริการจำหน่าย
# 11    11  ...  เป็นผู้ให้บริการจำหน่าย
# 12    12  ...  เป็นผู้ให้บริการจำหน่าย
# 13    13  ...  เป็นผู้ให้บริการจำหน่าย
# 14    14  ...  เป็นผู้ให้บริการจำหน่าย
# 15    15  ...  เป็นผู้ให้บริการจำหน่าย
#
# [16 rows x 9 columns]

# %%
data1_df = data1_df.rename(columns={'Unnamed: 5' : 'ราคาเสนอ', 'Unnamed: 7': 'ราคาซื้อ'})
data1_df #เปลี่ยนชื่อ colum
# Out:
#    ลำดับ  ... เหตุผลที่คัดเลือกโดยสรุป
# 0    ที่  ...                      NaN
# 1      1  ...  เป็นผู้ให้บริการจำหน่าย
# 2      2  ...  เป็นผู้ให้บริการจำหน่าย
# 3      3  ...  เป็นผู้ให้บริการจำหน่าย
# 4      4  ...  เป็นผู้ให้บริการจำหน่าย
# 5      5  ...  เป็นผู้ให้บริการจำหน่าย
# 6      6  ...  เป็นผู้ให้บริการจำหน่าย
# 7      7  ...  เป็นผู้ให้บริการจำหน่าย
# 8      8  ...  เป็นผู้ให้บริการจำหน่าย
# 9      9  ...  เป็นผู้ให้บริการจำหน่าย
# 10    10  ...  เป็นผู้ให้บริการจำหน่าย
# 11    11  ...  เป็นผู้ให้บริการจำหน่าย
# 12    12  ...  เป็นผู้ให้บริการจำหน่าย
# 13    13  ...  เป็นผู้ให้บริการจำหน่าย
# 14    14  ...  เป็นผู้ให้บริการจำหน่าย
# 15    15  ...  เป็นผู้ให้บริการจำหน่าย
#
# [16 rows x 9 columns]

# %%
data2_df = pd.read_excel(data_path,sheet_name='พย.57',header=4,skipfooter=30)
data2_df
# Out:
#                                                 ลำดับ  ...  เหตุผลที่คัดเลือกโดยสรุป
# 0                                                 ที่  ...                       NaN
# 1                                                   1  ...   เป็นผู้ให้บริการจำหน่าย
# 2                                                   2  ...            เป็นผู้จำหน่าย
# 3                                                   3  ...            เป็นผู้จำหน่าย
# 4                                                   4  ...            เป็นผู้จำหน่าย
# 5                                                   5  ...            เป็นผู้จำหน่าย
# 6                                                   6  ...            เป็นผู้จำหน่าย
# 7                                                   7  ...            เป็นผู้จำหน่าย
# 8                                                   8  ...            เป็นผู้จำหน่าย
# 9                                                   9  ...            เป็นผู้จำหน่าย
# ...

# %%
data_a = pd.concat([data1_df,data2_df])
data_a
# Out:
#    ลำดับ  ... Unnamed: 7
# 0    ที่  ...        NaN
# 1      1  ...        NaN
# 2      2  ...        NaN
# 3      3  ...        NaN
# 4      4  ...        NaN
# ..   ...  ...        ...
# 46    33  ...        NaN
# 47    34  ...        NaN
# 48    35  ...        NaN
# 49    36  ...        NaN
# 50    37  ...        NaN
#
# [67 rows x 11 columns]

# %%
data3_df = data_a.rename(columns={'Unnamed: 5':'ราคาเสนอ','Unnamed: 7':'ราคาาซื้อ'})
data3_df
# Out:
#    ลำดับ  ... ราคาาซื้อ
# 0    ที่  ...       NaN
# 1      1  ...       NaN
# 2      2  ...       NaN
# 3      3  ...       NaN
# 4      4  ...       NaN
# ..   ...  ...       ...
# 46    33  ...       NaN
# 47    34  ...       NaN
# 48    35  ...       NaN
# 49    36  ...       NaN
# 50    37  ...       NaN
#
# [67 rows x 11 columns]
